# %% [markdown]
# <a href="https://colab.research.google.com/github/mrjeevan/Python-Workshop/blob/master/Day_2_sesson_1_Exercise_programs_lists.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
mul_of_3 = [x*3 for x in range(201)]
print(mul_of_3)
# Out:
# [0, 3, 6, 9, 12, 15, 18, 21, 24, 27, 30, 33, 36, 39, 42, 45, 48, 51, 54, 57, 60, 63, 66, 69, 72, 75, 78, 81, 84, 87, 90, 93, 96, 99, 102, 105, 108, 111, 114, 117, 120, 123, 126, 129, 132, 135, 138, 141, 144, 147, 150, 153, 156, 159, 162, 165, 168, 171, 174, 177, 180, 183, 186, 189, 192, 195, 198, 201, 204, 207, 210, 213, 216, 219, 222, 225, 228, 231, 234, 237, 240, 243, 246, 249, 252, 255, 258, 261, 264, 267, 270, 273, 276, 279, 282, 285, 288, 291, 294, 297, 300, 303, 306, 309, 312, 315, 318, 321, 324, 327, 330, 333, 336, 339, 342, 345, 348, 351, 354, 357, 360, 363, 366, 369, 372, 375, 378, 381, 384, 387, 390, 393, 396, 399, 402, 405, 408, 411, 414, 417, 420, 423, 426, 429, 432, 435, 438, 441, 444, 447, 450, 453, 456, 459, 462, 465, 468, 471, 474, 477, 480, 483, 486, 489, 492, 495, 498, 501, 504, 507, 510, 513, 516, 519, 522, 525, 528, 531, 534, 537, 540, 543, 546, 549, 552, 555, 558, 561, 564, 567, 570, 573, 576, 579, 582, 585, 588, 591, 594, 597, 600]

# %%
div_by_7_and_5 = [x  for x in range(1000,2001) if x%5 == 0 and x%7 == 0]
print(div_by_7_and_5)
# Out:
# [1015, 1050, 1085, 1120, 1155, 1190, 1225, 1260, 1295, 1330, 1365, 1400, 1435, 1470, 1505, 1540, 1575, 1610, 1645, 1680, 1715, 1750, 1785, 1820, 1855, 1890, 1925, 1960, 1995]

# %%
from math import sqrt
perfect_squares= [x for x in range(500,1001) if sqrt(x) == int(sqrt(x)) and x%5 == 0]
print(perfect_squares)
# Out:
# [625, 900]

# %%
x = [int(x) for x in input('Input list :').split()]
print(f'Avrage is : {sum(x)/len(x)}')
# Out:
# Input list :5 5 5 5 5 5 5
# Avrage is : 5.0

# %%
odd = []
even = []

blank = [even.append(x) if x%2 == 0 else odd.append(x) for x in range(500,1001)]
print(f'odd : {odd} \neven : {even}')

mul_of_5 = [x for x in range(500,1001,5)]
print(mul_of_5)
     # or
mul_of_5_ = [x for x in range(500,1001) if x%5 == 0 ]  # extra if condition will be checked for all elements in loop
print(mul_of_5_)
# Out:
# odd : [501, 503, 505, 507, 509, 511, 513, 515, 517, 519, 521, 523, 525, 527, 529, 531, 533, 535, 537, 539, 541, 543, 545, 547, 549, 551, 553, 555, 557, 559, 561, 563, 565, 567, 569, 571, 573, 575, 577, 579, 581, 583, 585, 587, 589, 591, 593, 595, 597, 599, 601, 603, 605, 607, 609, 611, 613, 615, 617, 619, 621, 623, 625, 627, 629, 631, 633, 635, 637, 639, 641, 643, 645, 647, 649, 651, 653, 655, 657, 659, 661, 663, 665, 667, 669, 671, 673, 675, 677, 679, 681, 683, 685, 687, 689, 691, 693, 695, 697, 699, 701, 703, 705, 707, 709, 711, 713, 715, 717, 719, 721, 723, 725, 727, 729, 731, 733, 735, 737, 739, 741, 743, 745, 747, 749, 751, 753, 755, 757, 759, 761, 763, 765, 767, 769, 771, 773, 775, 777, 779, 781, 783, 785, 787, 789, 791, 793, 795, 797, 799, 801, 803, 805, 807, 809, 811, 813, 815, 817, 819, 821, 823, 825, 827, 829, 831, 833, 835, 837, 839, 841, 843, 845, 847, 849, 851, 853, 855, 857, 859, 861, 863, 865, 867, 869, 871, 873, 875, 877, 879, 881, 883, 885, 887, 889, 891, 893, 895, 8
# ...

# %%
l = [(x,x**2) for x in range(int(input('Enter Number : ')))]
print(l)
# Out:
# Enter Number : 300
# ...

# %%
l = (x for x in input('Enter Names : ').split()) # tuple
l = sorted(l,key = lambda x: len(x))
print(l)
# Out:
# Enter Names : Name1 NoName FullName JustName
# ['Name1', 'NoName', 'FullName', 'JustName']

# %%
l = []

def inp():
  name = input('Name : ')
  rolno = input(' Rol No : ')
  return (name,rolno)  # returns tuples

n = int(input('Number of Students : '))
for x in range(n):
  l.append(inp())

print(f'Original : {l}')

l.sort(key = lambda x:x[1])
print(f'According to Rol No : Ascending :{l}')
print(f'According to Rol No : Descending :{l[::-1]}')

l.sort(key = lambda x:x[0])
print(f'According to Name : Ascending :{l}')
print(f'According to Name : Descending :{l[::-1]}')
# Out:
# Number of Students : 4
# Name : abcdef
#  Rol No : 4
# Name : ghijk
#  Rol No : 2
# Name : rtty
#  Rol No : 56
# Name : utf-8
#  Rol No : 13
# Original : [('abcdef', '4'), ('ghijk', '2'), ('rtty', '56'), ('utf-8', '13')]
# According to Rol No : Ascending :[('utf-8', '13'), ('ghijk', '2'), ('abcdef', '4'), ('rtty', '56')]
# According to Rol No : Descending :[('rtty', '56'), ('abcdef', '4'), ('ghijk', '2'), ('utf-8', '13')]
# According to Name : Ascending :[('abcdef', '4'), ('ghijk', '2'), ('rtty', '56'), ('utf-8', '13')]
# According to Name : Descending :[('utf-8', '13'), ('rtty', '56'), ('ghijk', '2'), ('abcdef', '4')]
